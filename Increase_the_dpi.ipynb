# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('F:\\7th sem\\Resume\\B&E_mechanism.png')# (we need to use double '\', otherwise it will show error) #just reading
imgplot = plt.imshow(img)#img variable stores the image now
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imgpath = 'F:\\7th sem\\Resume\\B&E_mechanism.png'

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

from PIL import Image

img = Image.open(imgpath)
print(img.size)

width, height = img.size
# img.thumbnail((width * 2,height * 2), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img)
plt.savefig('Figure3_dpi_800', dpi = 800)
# Out:
# (1024, 395)
